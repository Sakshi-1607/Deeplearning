# %%
from tensorflow.keras.datasets import mnist
# Modified national institute ofStandards and technology worked on handwritten digit recognization.
# so it was named after it
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt

# %%
# Split dataset into train and test
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
print('x_train:',x_train.shape)
print('y_train:',y_train.shape)
print('x_test:',x_test.shape)
print('y_test:',y_test.shape)
# Out:
# x_train: (60000, 28, 28)
# y_train: (60000,)
# x_test: (10000, 28, 28)
# y_test: (10000,)

# %%
x,y=12,15
print(x)
print(y)
# Out:
# 12
# 15

# %%
# Standardise x_train, y_train
x_train,x_test=x_train/255.0,x_test/255.0

# %%
import tensorflow as tf

# %%
# Convert labels to categories
y_train_cat=tf.keras.utils.to_categorical(y_train,10)
y_test_cat=tf.keras.utils.to_categorical(y_train,10)

# %%
txt="Mahendra Singh Dhoni"
txt1=txt.split(" ")
print(txt1)
for x in range(len(txt1)):
    txt2=txt1[x][0]
    print(txt2)
# Out:
# ['Mahendra', 'Singh', 'Dhoni']
# M
# S
# D

# %%
def short():
    x=str(input())
    txt1=x.split(" ")
    print(txt1)
    for x in range(len(txt1)):
        txt2=txt1[x][0]
        print(txt2)

# %%
short()
# Out:
#  Deepak Sharma
# ['Deepak', 'Sharma']
# D
# S

# %%
# Define a model function
def bulid_model(optimizer):
    model=Sequential([Flatten(input_shape=(28,28)),Dense(64,activation='relu'),Dense(10,activation='softmax')])
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    return model

# %%
# BUILDING THE MODEL BY INTERCHANGING OPTIMIZER
# adam optimizer : 0.001
# SGD optimizer (stochastic Gradient Descent) : 0.1-0-01
import tensorflow as tf
model_sgd = bulid_model(tf.keras.optimizers.SGD(learning_rate=0.01))
# Out:
# C:\Users\saksh\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history_sgd = model_sgd.fit(x_train,y_train_cat,epochs=7,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6874 - loss: 1.1682 - val_accuracy: 0.8974 - val_loss: 0.3863
# Epoch 2/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8940 - loss: 0.3882 - val_accuracy: 0.9143 - val_loss: 0.3166
# Epoch 3/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9104 - loss: 0.3233 - val_accuracy: 0.9215 - val_loss: 0.2856
# Epoch 4/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9159 - loss: 0.2978 - val_accuracy: 0.9269 - val_loss: 0.2609
# Epoch 5/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9261 - loss: 0.2664 - val_accuracy: 0.9317 - val_loss: 0.2456
# Epoch 6/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9312 - loss: 0.2493 - val_accuracy: 0.9346 - val_loss: 0.2302
# Epoch 7/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9352 - loss: 0.2327 - val_accuracy: 0.9390 - val_loss: 0.2180

# %%
model_adam=bulid_model(tf.keras.optimizers.Adam(learning_rate=0.001))

# %%
history_adam=model_adam.fit(x_train,y_train_cat,epochs=7,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8496 - loss: 0.5382 - val_accuracy: 0.9501 - val_loss: 0.1776
# Epoch 2/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9507 - loss: 0.1714 - val_accuracy: 0.9573 - val_loss: 0.1461
# Epoch 3/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9651 - loss: 0.1176 - val_accuracy: 0.9624 - val_loss: 0.1222
# Epoch 4/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9726 - loss: 0.0943 - val_accuracy: 0.9667 - val_loss: 0.1130
# Epoch 5/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9775 - loss: 0.0790 - val_accuracy: 0.9678 - val_loss: 0.1098
# Epoch 6/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9817 - loss: 0.0637 - val_accuracy: 0.9672 - val_loss: 0.1043
# Epoch 7/7
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9848 - loss: 0.0505 - val_accuracy: 0.9667 - val_loss: 0.1137

# %%
# compare_performance
plt.plot(history_sgd.history['val_accuracy'],label='SGD-val acc')
plt.plot(history_adam.history['val_accuracy'],label='SGD-val acc')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("validation - Accuracy Comparision")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Verify overfitting or underfitting in the model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
import tensorflow

# %%
# Load the data
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_test/255.0,x_test/255.0

# %%
# preprocess the data
y_train_cat=tensorflow.keras.utils.to_categorical(y_train)
y_test_cat=tensorflow.keras.utils.to_categorical(y_test)

# %%
model=Sequential([Flatten(input_shape=(28,28)),Dense(256,activation='relu'),Dense(256,activation='relu'),Dense(10,activation='softmax')])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train_cat,epochs=15,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.1023 - loss: 2.3309 - val_accuracy: 0.1075 - val_loss: 2.3061
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1349 - loss: 2.2854 - val_accuracy: 0.1235 - val_loss: 2.3035
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1586 - loss: 2.2603 - val_accuracy: 0.1040 - val_loss: 2.3221
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.1840 - loss: 2.2260 - val_accuracy: 0.0965 - val_loss: 2.3771
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.2146 - loss: 2.1717 - val_accuracy: 0.1105 - val_loss: 2.3796
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2540 - loss: 2.0988 - val_accuracy: 0.1135 - val_loss: 2.4668
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2940 - loss: 2.0078 - val_accuracy: 0.1125 - val_loss: 2.5375
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3369 - loss: 1.9081 - val_accuracy: 0.1035 - val_loss: 2.6084
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3920 - loss: 1.7680 - val_accuracy: 0.1085 - val_loss: 2.6891
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4427 - loss: 1.6308 - val_accuracy: 0.1055 - val_loss: 2.7744
# Epoch 11/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4905 - loss: 1.5112 - val_accuracy: 0.1120 - val_loss: 2.8945
# Epoch 12/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5552 - loss: 1.3491 - val_accuracy: 0.1100 - val_loss: 3.1306
# Epoch 13/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5914 - loss: 1.2134 - val_accuracy: 0.1085 - val_loss: 3.2312
# Epoch 14/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6352 - loss: 1.1057 - val_accuracy: 0.1060 - val_loss: 3.4481
# Epoch 15/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6878 - loss: 0.9710 - val_accuracy: 0.1085 - val_loss: 3.6992

# %%
# draw a line-plot
plt.plot(history.history['loss'],label='Train loss')
plt.plot(history.history['val_loss'],label='Test loss')
plt.title('Overfitting')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# prevent overfitting using L2 regularisation
from tensorflow.keras.regularizers import l2 # importing L2 regularisation

# %%
model=Sequential([Flatten(input_shape=(28,28)),Dense(256,activation='relu',kernel_regularizer=l2(0.001)),Dense(10,activation='softmax')])

# %%
# Hyperparameter Tuning with learning rate,batch size,epochs
model=Sequential([Flatten(input_shape=(28,28)),Dense(128,activation='relu'),Dense(10,activation='softmax')])
model.compile(optimizer=tensorflow.keras.optimizers.Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# train the model
history=model.fit(x_train,y_train_cat,epochs=10,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1023 - loss: 2.3510 - val_accuracy: 0.0945 - val_loss: 2.3105
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1369 - loss: 2.2816 - val_accuracy: 0.1040 - val_loss: 2.3162
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1585 - loss: 2.2586 - val_accuracy: 0.1040 - val_loss: 2.3234
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1752 - loss: 2.2341 - val_accuracy: 0.1055 - val_loss: 2.3305
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2023 - loss: 2.2017 - val_accuracy: 0.1045 - val_loss: 2.3392
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2177 - loss: 2.1668 - val_accuracy: 0.0975 - val_loss: 2.3785
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2344 - loss: 2.1279 - val_accuracy: 0.1015 - val_loss: 2.3835
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2657 - loss: 2.0811 - val_accuracy: 0.1055 - val_loss: 2.4155
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2824 - loss: 2.0311 - val_accuracy: 0.1090 - val_loss: 2.4374
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3086 - loss: 1.9862 - val_accuracy: 0.1015 - val_loss: 2.4785

# %%
# draw a line-plot
plt.plot(history.history['accuracy'],label='Train Accuracy')
plt.plot(history.history['val_accuracy'],label='Test Accuracy')
plt.title('Accuracy with Hyperparameter tuning')
plt.xlabel('Epochs')
plt.ylabel('accuacy')
plt.legend()
plt.show()
